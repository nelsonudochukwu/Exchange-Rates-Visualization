# %%
import pandas as pd

exchange_rates = pd.read_csv("C:\\Users\\NELSON ESTHER\\Desktop\\datasets for projects\\Exhange rates dataset\\euro-daily-hist_1999_2022.csv")
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2024-09-27                1.618           1.9558            6.0668
# 1   2024-09-26               1.6217           1.9558            6.0372
# 2   2024-09-25               1.6276           1.9558            6.1104
# 3   2024-09-24               1.6237           1.9558             6.137
# 4   2024-09-23               1.6274           1.9558            6.1976
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5036          0.942                    7.823              NaN
# 1             1.5025         0.9452                   7.8213              NaN
# 2             1.5044         0.9495                   7.8692              NaN
# 3             1.5033         0.9439                    7.829              NaN
# 4             1.5065         0.9448                   7.8438              NaN
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          25.158           7.457  ...          4.9764               NaN
# 1          25.159          7.4572  ...          4.9759               NaN
# 2          25.123          7.4575  ...          4.9760               NaN
# 3          25.155          7.4571  ...          4.9756               NaN
# 4          25.098          7.4581  ...          4.9742               NaN
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0           11.273              1.4305                NaN              NaN
# 1             11.3              1.4328                NaN              NaN
# 2           11.311              1.4378                NaN              NaN
# 3          11.2935              1.4341                NaN              NaN
# 4           11.362              1.4357                NaN              NaN
#
#   [Thai baht ] [Turkish lira ] [US dollar ]  [South African rand ]
# 0       36.135         38.1336       1.1158                19.1092
# 1       36.215         38.1022       1.1155                 19.238
# 2       36.599         38.2090       1.1194                19.1932
# 3       36.569         38.0064       1.1133                19.2869
# 4       36.654         37.9745       1.1119                19.3253
#
# [5 rows x 41 columns]

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6650   1999-01-08               1.8406              NaN               NaN
# 6651   1999-01-07               1.8474              NaN               NaN
# 6652   1999-01-06               1.8820              NaN               NaN
# 6653   1999-01-05               1.8944              NaN               NaN
# 6654   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6650             1.7643         1.6138                      NaN
# 6651             1.7602         1.6165                      NaN
# 6652             1.7711         1.6116                      NaN
# 6653             1.7965         1.6123                      NaN
# 6654             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# 6650          0.58187          34.938          7.4433  ...          1.3143
# 6651          0.58187          34.886          7.4431  ...          1.3092
# 6652          0.58200          34.850          7.4452  ...          1.3168
# 6653          0.58230          34.917          7.4495  ...          1.3168
# 6654          0.58231          35.107          7.4501  ...          1.3111
#
#      [Russian rouble ] [Swedish krona ] [Singapore dollar ]  \
# 6650           27.2075           9.1650              1.9537
# 6651           26.9876           9.1800              1.9436
# 6652           27.4315           9.3050              1.9699
# 6653           26.5876           9.4025              1.9655
# 6654           25.2875           9.4696              1.9554
#
#      [Slovenian tolar ] [Slovak koruna ] [Thai baht ] [Turkish lira ]  \
# 6650           188.8400           42.560      42.5590          0.3718
# 6651           188.8000           42.765      42.1678          0.3701
# 6652           188.7000           42.778      42.6949          0.3722
# 6653           188.7750           42.848      42.5048          0.3728
# 6654           189.0450           42.991      42.6799          0.3723
#
#      [US dollar ]  [South African rand ]
# 6650       1.1659                 6.7855
# 6651       1.1632                 6.8283
# 6652       1.1743                 6.7307
# 6653       1.1790                 6.7975
# 6654       1.1789                 6.9358
#
# [5 rows x 41 columns]

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6655 entries, 0 to 6654
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6655 non-null   object
#  1   [Australian dollar ]      6655 non-null   object
#  2   [Bulgarian lev ]          6253 non-null   object
#  3   [Brazilian real ]         6387 non-null   object
#  4   [Canadian dollar ]        6655 non-null   object
#  5   [Swiss franc ]            6655 non-null   object
#  6   [Chinese yuan renminbi ]  6387 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6655 non-null   object
#  9   [Danish krone ]           6655 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6655 non-null   object
#  12  [Greek drachma ]          520 non-null    object
#  13  [Hong Kong dollar ]       6655 non-null   object
#  14  [Croatian kuna ]          5941 non-null   object
#  15  [Hungarian forint ]       6655 non-null   object
#  16  [Indonesian rupiah ]      6655 non-null   object
#  17  [Israeli shekel ]         6387 non-null   object
#  18  [Indian rupee ]           6387 non-null   object
#  19  [Iceland krona ]          4248 non-null   float64
#  20  [Japanese yen ]           6655 non-null   object
#  21  [Korean won ]             6655 non-null   object
#  22  [Lithuanian litas ]       4159 non-null   object
#  23  [Latvian lats ]           3904 non-null   object
#  24  [Maltese lira ]           2346 non-null   object
#  25  [Mexican peso ]           6655 non-null   object
#  26  [Malaysian ringgit ]      6655 non-null   object
#  27  [Norwegian krone ]        6655 non-null   object
#  28  [New Zealand dollar ]     6655 non-null   object
#  29  [Philippine peso ]        6655 non-null   object
#  30  [Polish zloty ]           6655 non-null   object
#  31  [Romanian leu ]           6593 non-null   float64
#  32  [Russian rouble ]         5994 non-null   object
#  33  [Swedish krona ]          6655 non-null   object
#  34  [Singapore dollar ]       6655 non-null   object
#  35  [Slovenian tolar ]        2085 non-null   object
#  36  [Slovak koruna ]          2608 non-null   object
#  37  [Thai baht ]              6655 non-null   object
#  38  [Turkish lira ]           6593 non-null   float64
#  39  [US dollar ]              6655 non-null   object
#  40  [South African rand ]     6655 non-null   object
# dtypes: float64(3), object(38)
# memory usage: 2.1+ MB

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar', 
                               'Period\\Unit:': 'Time'}, inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)
exchange_rates.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          35.107          7.4501  ...          1.3111           25.2875
# 1          34.917          7.4495  ...          1.3168           26.5876
# 2          34.850          7.4452  ...          1.3168           27.4315
# 3          34.886          7.4431  ...          1.3092           26.9876
# 4          34.938          7.4433  ...          1.3143           27.2075
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0           9.4696              1.9554           189.0450           42.991
# 1           9.4025              1.9655           188.7750           42.848
# 2           9.3050              1.9699           188.7000           42.778
# 3           9.1800              1.9436           188.8000           42.765
# 4           9.1650              1.9537           188.8400           42.560
#
#   [Thai baht ] [Turkish lira ] US_dollar  [South African rand ]
# 0      42.6799          0.3723    1.1789                 6.9358
# 1      42.5048          0.3728    1.1790                 6.7975
# 2      42.6949          0.3722    1.1743                 6.7307
# 3      42.1678          0.3701    1.1632                 6.8283
# 4      42.5590          0.3718    1.1659                 6.7855
#
# [5 rows x 41 columns]

# %%
# exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
#                                'Period\\Unit:': 'Time'},
#                       inplace=True)
# exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
# exchange_rates.sort_values('Time', inplace=True)
# exchange_rates.reset_index(drop=True, inplace=True)
# exchange_rates.head()

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()
euro_to_dollar['US_dollar'].value_counts()
# Out:
# -         62
# 1.2276     9
# 1.0808     8
# 1.0867     8
# 1.1215     8
#           ..
# 1.4741     1
# 1.4720     1
# 1.4554     1
# 1.4649     1
# 1.1121     1
# Name: US_dollar, Length: 3798, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(exchange_rates['Time'], exchange_rates['[Australian dollar ]'])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert to numeric and drop missing values
euro_to_dollar['US_dollar'] = pd.to_numeric(euro_to_dollar['US_dollar'], errors='coerce')
euro_to_dollar.dropna(inplace=True)

# Plot the data
plt.figure(figsize=(7, 5))
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(9,6))

plt.subplot(3,2,1)
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.title('Original values', weight='bold')

for i, rolling_mean in zip([2, 3, 4, 5, 6],
                           [7, 30, 50, 100, 365]):
    plt.subplot(3,2,i)
    plt.plot(euro_to_dollar['Time'],
             euro_to_dollar['US_dollar'].rolling(rolling_mean).mean())
    plt.title('Rolling Window:' + str(rolling_mean), weight='bold')
    
plt.tight_layout() # Auto-adjusts the padding between subplots
plt.show()

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()
euro_to_dollar
# Out:
#            Time  US_dollar  rolling_mean
# 0    1999-01-04     1.1789           NaN
# 1    1999-01-05     1.1790           NaN
# 2    1999-01-06     1.1743           NaN
# 3    1999-01-07     1.1632           NaN
# 4    1999-01-08     1.1659           NaN
# ...         ...        ...           ...
# 6650 2024-09-23     1.1119      1.108197
# 6651 2024-09-24     1.1133      1.108870
# 6652 2024-09-25     1.1194      1.109453
# 6653 2024-09-26     1.1155      1.109933
# 6654 2024-09-27     1.1158      1.110480
#
# [6593 rows x 3 columns]

# %%
financial_crisis = euro_to_dollar.copy(
                   )[(euro_to_dollar['Time'].dt.year >= 2006
                   ) & (euro_to_dollar['Time'].dt.year <= 2009)]
financial_crisis_7_8 = euro_to_dollar.copy(
                   )[(euro_to_dollar.Time.dt.year >= 2007
                   ) & (euro_to_dollar.Time.dt.year <= 2008)]

# %%
### Adding the FiveThirtyEight style
import matplotlib.style as style
style.use('fivethirtyeight')

### Adding the plot
fig,ax = plt.subplots(figsize=(8,3))
ax.plot(financial_crisis['Time'],
        financial_crisis['rolling_mean'],
        linewidth=1, color='#A6D785')

### Highlighting the 2007-2008 period
ax.plot(financial_crisis_7_8['Time'],
        financial_crisis_7_8['rolling_mean'],
        linewidth=3, color='#e23d28')

### Highlihting the peak of the crisis
ax.axvspan(xmin=13955, xmax=14125, ymin=0.09,
           alpha=0.3, color='grey')
    
### Adding separate tick labels
ax.set_xticklabels([])
ax.set_yticklabels([])

x = 13149.0
for year in ['2006', '2007', '2008', '2009', '2010']:
    ax.text(x, 1.13, year, alpha=0.5, fontsize=11)
    x += 181

y = 1.193   
for rate in ['1.2', '1.3', '1.4', '1.5']:
    ax.text(13149.0, y, rate, alpha=0.5, fontsize=11)
    y += 0.1

    ## Adding a title and a subtitle    
ax.text(13149.0, 1.67, "Euro-USD rate peaked at 1.59 during 2007-2008's financial crisis",
        weight='bold')
ax.text(13149.0, 1.63, 'Euro-USD exchange rates between 2006 and 2010',
        size=12)

### Adding a signature
ax.text(13149.0, 1.07, '©DATAQUEST' + ' '*94 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

### Add some transparency to the grid
ax.grid(alpha=0.5)

plt.show()
